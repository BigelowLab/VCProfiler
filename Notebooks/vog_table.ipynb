# %%
import pandas as pd

# %%
tbl = "/mnt/scgc/simon/simonsproject/jb_vs_test/viral_dbs/VOG/vog.annotations.tsv"

# %%
df = pd.read_csv(tbl, sep="\t")

# %%
df
# Out:
#       #GroupName  ProteinCount  SpeciesCount FunctionalCategory  \
# 0       VOG00001           502            59                 Xu
# 1       VOG00002           439            32                 Xu
# 2       VOG00003           629           132                 Xu
# 3       VOG00004           687           532                 Xu
# 4       VOG00005           222            59                 Xu
# 5       VOG00006           836           656                 Xu
# 6       VOG00007           413           373                 Xu
# 7       VOG00008            88            30                 Xu
# 8       VOG00009           349           202                 Xu
# 9       VOG00010            98            39                 Xu
# 10      VOG00011           105            81                 Xu
# 11      VOG00012            86            56                 Xu
# 12      VOG00013            61            33                 Xu
# 13      VOG00014            78             4                 Xu
# ...
